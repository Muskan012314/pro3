# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()

# %%
import matplotlib.pyplot as plt
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]


plt.plot(years, kohli, color='black', linestyle='--', label='kohli')
plt.plot(years, sehwag, color='green', linestyle='-.', label='sehwag')

plt.xlabel("year")
plt.ylabel("runs scored")
plt.title("performance comparison")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np

# %%
for i in range(5):
    plt.plot(np.random.rand(10), linewidth=1)

plt.title("too much data can be confusing!")
plt.grid(True)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

x = np.arange(len(years))
width = 0.25

plt.bar(x - width, sachin, width=width, label="sachin")
plt.bar(x, sehwag, width=width, label="sehwag")
plt.bar(x + width, kohli, width=width, label="kohli")

plt.xlabel("year")
plt.ylabel("runs scored")
plt.title("performance comparison")
plt.xticks(x, years)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Stack Plot Example
import matplotlib.pyplot as plt

# Days of the week
days = [1, 2, 3, 4, 5, 6, 7]
studying = [2, 3, 2, 2, 3, 4, 2]
playing = [2, 1, 2, 3, 2, 1, 2]
watching_tv = [2, 2, 1, 2, 3, 2, 1]
sleeping = [5, 6, 7, 5, 5, 5, 7]

labels = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']

plt.figure(figsize=(10, 6))
plt.stackplot(
    days,
    studying,
    playing,
    watching_tv,
    sleeping,
    labels=labels,
    colors=colors,
    alpha=0.8
)

plt.legend(loc='upper left')
plt.title('Weekly Activity Tracker')
plt.xlabel('Days')
plt.ylabel('Hours')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

languages = ['Python', 'Java', 'C++', 'JavaScript', 'C#', 'Ruby', ]
usage = [30, 20, 10, 10, 5, 4,]
colors= ['#377eb8',
    '#ff7f00',  
    '#4daf4a',  
    '#f781bf',  
    '#a65628',  
    '#984ea3',]
plt.pie(
    usage,
    labels=languages,
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Programming Language Usage (Crowded Example)")
plt.show()
